# %%
# Importing libraries
import pandas as pd
import numpy as np

# %%
# Load the dataset

df = pd.read_csv("dailyIntensities_merged.csv")

# %%
df
# Out:
#              Id ActivityDay  SedentaryMinutes  LightlyActiveMinutes  \
# 0    1503960366  04-12-2016               728                   328
# 1    1503960366   4/13/2016               776                   217
# 2    1503960366   4/14/2016              1218                   181
# 3    1503960366   4/15/2016               726                   209
# 4    1503960366   4/16/2016               773                   221
# ..          ...         ...               ...                   ...
# 935  8877689391  05-08-2016              1174                   245
# 936  8877689391  05-09-2016              1131                   217
# 937  8877689391  05-10-2016              1187                   224
# 938  8877689391  05-11-2016              1127                   213
# 939  8877689391  05-12-2016               770                   137
#
#      FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                     13                 25                     0.00
# ...

# %% [markdown]
# ### Quick Overview

# %%
# Display first few rows
df.head()
# Out:
#            Id ActivityDay  SedentaryMinutes  LightlyActiveMinutes  \
# 0  1503960366  04-12-2016               728                   328
# 1  1503960366   4/13/2016               776                   217
# 2  1503960366   4/14/2016              1218                   181
# 3  1503960366   4/15/2016               726                   209
# 4  1503960366   4/16/2016               773                   221
#
#    FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                   13                 25                      0.0
# 1                   19                 21                      0.0
# 2                   11                 30                      0.0
# 3                   34                 29                      0.0
# 4                   10                 36                      0.0
#
#    LightActiveDistance  ModeratelyActiveDistance  VeryActiveDistance
# 0                  6.1                       0.6                 1.9
# ...

# %%
# check dataset information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDay               940 non-null    object
#  2   SedentaryMinutes          940 non-null    int64
#  3   LightlyActiveMinutes      940 non-null    int64
#  4   FairlyActiveMinutes       940 non-null    int64
#  5   VeryActiveMinutes         940 non-null    int64
#  6   SedentaryActiveDistance   940 non-null    float64
#  7   LightActiveDistance       940 non-null    float64
#  8   ModeratelyActiveDistance  940 non-null    float64
#  9   VeryActiveDistance        940 non-null    float64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 73.6+ KB

# %%
# shape

df.shape
# Out:
# (940, 10)

# %%
# data types

df.dtypes
# Out:
# Id                            int64
# ActivityDay                  object
# SedentaryMinutes              int64
# LightlyActiveMinutes          int64
# FairlyActiveMinutes           int64
# VeryActiveMinutes             int64
# SedentaryActiveDistance     float64
# LightActiveDistance         float64
# ModeratelyActiveDistance    float64
# VeryActiveDistance          float64
# dtype: object

# %%
# Statistics of dataset

df.describe()
# Out:
#                  Id  SedentaryMinutes  LightlyActiveMinutes  \
# count  9.400000e+02        940.000000            940.000000
# mean   4.855407e+09        991.210638            192.812766
# std    2.424805e+09        301.267437            109.174700
# min    1.503960e+09          0.000000              0.000000
# 25%    2.320127e+09        729.750000            127.000000
# 50%    4.445115e+09       1057.500000            199.000000
# 75%    6.962181e+09       1229.500000            264.000000
# max    8.877689e+09       1440.000000            518.000000
#
#        FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# count           940.000000         940.000000               940.000000
# mean             13.564894          21.164894                 0.001606
# std              19.987404          32.844803                 0.007346
# min               0.000000           0.000000                 0.000000
# ...

# %%
# Check missing values

df.isnull().sum()
# Out:
# Id                          0
# ActivityDay                 0
# SedentaryMinutes            0
# LightlyActiveMinutes        0
# FairlyActiveMinutes         0
# VeryActiveMinutes           0
# SedentaryActiveDistance     0
# LightActiveDistance         0
# ModeratelyActiveDistance    0
# VeryActiveDistance          0
# dtype: int64

# %%
# check duplicate records

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Note: No duplicates and no missing values

# %%
df['ActivityDay'] # Need to change the format
# Out:
# 0      04-12-2016
# 1       4/13/2016
# 2       4/14/2016
# 3       4/15/2016
# 4       4/16/2016
#           ...
# 935    05-08-2016
# 936    05-09-2016
# 937    05-10-2016
# 938    05-11-2016
# 939    05-12-2016
# Name: ActivityDay, Length: 940, dtype: object

# %%
df['ActivityDay'] = pd.to_datetime(df['ActivityDay'], format='mixed', dayfirst=True)

df['ActivityDay'] = df['ActivityDay'].dt.strftime('%d/%m/%Y')

# %%
df['ActivityDay'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Id                          0
# ActivityDay                 0
# SedentaryMinutes            0
# LightlyActiveMinutes        0
# FairlyActiveMinutes         0
# VeryActiveMinutes           0
# SedentaryActiveDistance     0
# LightActiveDistance         0
# ModeratelyActiveDistance    0
# VeryActiveDistance          0
# dtype: int64

# %%
df['ActivityDay']
# Out:
# 0      04/12/2016
# 1      13/04/2016
# 2      14/04/2016
# 3      15/04/2016
# 4      16/04/2016
#           ...
# 935    05/08/2016
# 936    05/09/2016
# 937    05/10/2016
# 938    05/11/2016
# 939    05/12/2016
# Name: ActivityDay, Length: 940, dtype: object

# %%
df['ActivityDay'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Save the clean dataset

# %%
df.to_csv("clean_dailyIntensities.csv", index=False)

# %% [markdown]
# # Loading the clean dataset

# %%
df = pd.read_csv("clean_dailyIntensities.csv")

# %%
df.head()
# Out:
#            Id ActivityDay  SedentaryMinutes  LightlyActiveMinutes  \
# 0  1503960366  04/12/2016               728                   328
# 1  1503960366  13/04/2016               776                   217
# 2  1503960366  14/04/2016              1218                   181
# 3  1503960366  15/04/2016               726                   209
# 4  1503960366  16/04/2016               773                   221
#
#    FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                   13                 25                      0.0
# 1                   19                 21                      0.0
# 2                   11                 30                      0.0
# 3                   34                 29                      0.0
# 4                   10                 36                      0.0
#
#    LightActiveDistance  ModeratelyActiveDistance  VeryActiveDistance
# 0                  6.1                       0.6                 1.9
# ...

# %%
df
# Out:
#              Id ActivityDay  SedentaryMinutes  LightlyActiveMinutes  \
# 0    1503960366  04/12/2016               728                   328
# 1    1503960366  13/04/2016               776                   217
# 2    1503960366  14/04/2016              1218                   181
# 3    1503960366  15/04/2016               726                   209
# 4    1503960366  16/04/2016               773                   221
# ..          ...         ...               ...                   ...
# 935  8877689391  05/08/2016              1174                   245
# 936  8877689391  05/09/2016              1131                   217
# 937  8877689391  05/10/2016              1187                   224
# 938  8877689391  05/11/2016              1127                   213
# 939  8877689391  05/12/2016               770                   137
#
#      FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                     13                 25                     0.00
# ...
