# %%
import pandas as pd

# %%
df = pd.read_csv("sleepDay_merged.csv")

# %%
df.head()
# Out:
#            Id                 SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  04/12/2016 12:00:00  AM                  1                 327
# 1  1503960366    4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366    4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366    4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366    4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %% [markdown]
# # Quick Overview

# %%
# few rows

df.head()
# Out:
#            Id                 SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  04/12/2016 12:00:00  AM                  1                 327
# 1  1503960366    4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366    4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366    4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366    4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
# Dataset info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  413 non-null    int64
#  1   SleepDay            413 non-null    object
#  2   TotalSleepRecords   413 non-null    int64
#  3   TotalMinutesAsleep  413 non-null    int64
#  4   TotalTimeInBed      413 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 16.3+ KB

# %%
# datatypes of the dataset

df.dtypes
# Out:
# Id                     int64
# SleepDay              object
# TotalSleepRecords      int64
# TotalMinutesAsleep     int64
# TotalTimeInBed         int64
# dtype: object

# %% [markdown]
# #### In this dataset, we mostly have numeric data

# %%
# Check missing values

df.isnull().sum()
# Out:
# Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64

# %%
# check duplicate records

df.duplicated().sum()
# Out:
# 3

# %%
# Remove duplicates

df = df.drop_duplicates()

# %%
# check duplicate records again

df.duplicated().sum()
# Out:
# 0

# %%
df["SleepDay"] # Need to convert the column into date
# Out:
# 0      04/12/2016 12:00:00  AM
# 1        4/13/2016 12:00:00 AM
# 2        4/15/2016 12:00:00 AM
# 3        4/16/2016 12:00:00 AM
# 4        4/17/2016 12:00:00 AM
#                 ...
# 408      4/30/2016 12:00:00 AM
# 409    05/01/2016 12:00:00  AM
# 410    05/02/2016 12:00:00  AM
# 411    05/03/2016 12:00:00  AM
# 412    05/04/2016 12:00:00  AM
# Name: SleepDay, Length: 410, dtype: object

# %% [markdown]
# ### Convert to dd/mm/yyyy

# %%
df['SleepDay'] = pd.to_datetime(df['SleepDay'], format='mixed')

# %%
df['SleepDay']
# Out:
# 0     2016-04-12
# 1     2016-04-13
# 2     2016-04-15
# 3     2016-04-16
# 4     2016-04-17
#          ...
# 408   2016-04-30
# 409   2016-05-01
# 410   2016-05-02
# 411   2016-05-03
# 412   2016-05-04
# Name: SleepDay, Length: 410, dtype: datetime64[ns]

# %% [markdown]
# ### Convert to dd/mm/yyyy

# %%
df['SleepDay'] = df['SleepDay'].dt.strftime('%d/%m/%Y')

# %% [markdown]
# ### Verify

# %%
df['SleepDay'].head()
# Out:
# 0    12/04/2016
# 1    13/04/2016
# 2    15/04/2016
# 3    16/04/2016
# 4    17/04/2016
# Name: SleepDay, dtype: object

# %% [markdown]
# # Saving clean dataset

# %%
df.to_csv("clean_sleepDay.csv", index = False)

# %% [markdown]
# # Loading the clean dataset

# %%
df = pd.read_csv("clean_sleepDay.csv")

# %%
df.head()
# Out:
#            Id    SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  12/04/2016                  1                 327
# 1  1503960366  13/04/2016                  2                 384
# 2  1503960366  15/04/2016                  1                 412
# 3  1503960366  16/04/2016                  2                 340
# 4  1503960366  17/04/2016                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %% [raw]
# Dataset is now successfully clean removing duplicate records and converting the SleepDay column from datetime format into a standardized day/month/year format.
