# %%
# Importing libraries
import pandas as pd
import numpy as np

# %%
# Load the dataset

df = pd.read_csv("dailyActivity_merged.csv")

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   04/12/2016       13162            8.5              8.5
# 1    1503960366    4/13/2016       10735            7.0              7.0
# 2    1503960366    4/14/2016       10460            6.7              6.7
# 3    1503960366    4/15/2016        9762            6.3              6.3
# 4    1503960366    4/16/2016       12669            8.2              8.2
# ..          ...          ...         ...            ...              ...
# 935  8877689391   05/08/2016       10686            8.1              8.1
# 936  8877689391   05/09/2016       20226           18.3             18.3
# 937  8877689391   05/10/2016       10733            8.1              8.1
# 938  8877689391   05/11/2016       21420           19.6             19.6
# 939  8877689391   05/12/2016        8064            6.1              6.1
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %% [markdown]
# ### Quick Overview

# %%
# Display first few rows
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   12/04/2016       13162            8.5              8.5
# 1  1503960366   13/04/2016       10735            7.0              7.0
# 2  1503960366   14/04/2016       10460            6.7              6.7
# 3  1503960366   15/04/2016        9762            6.3              6.3
# 4  1503960366   16/04/2016       12669            8.2              8.2
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                 1.9                       0.6
# 1                       0.0                 1.6                       0.7
# 2                       0.0                 2.4                       0.4
# 3                       0.0                 2.1                       1.3
# 4                       0.0                 2.7                       0.4
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
# check dataset information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %%
# shape

df.shape
# Out:
# (940, 15)

# %%
# data types

df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
# Statistics of dataset

df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489787         5.475532
# std    2.424805e+09   5087.150742       3.923801         3.906519
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.600000         2.600000
# 50%    4.445115e+09   7405.500000       5.250000         5.250000
# 75%    6.962181e+09  10727.000000       7.700000         7.700000
# max    8.877689e+09  36019.000000      28.000000        28.000000
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108723            1.504149                  0.567979
# std                    0.622038            2.658499                  0.882432
# ...

# %%
# Check missing values

df.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
# check duplicate records

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Note: No duplicates and no mising values

# %%
df['ActivityDate'] # Need to change the format
# Out:
# 0      04/12/2016
# 1       4/13/2016
# 2       4/14/2016
# 3       4/15/2016
# 4       4/16/2016
#           ...
# 935    05/08/2016
# 936    05/09/2016
# 937    05/10/2016
# 938    05/11/2016
# 939    05/12/2016
# Name: ActivityDate, Length: 940, dtype: object

# %%
df['ActivityDate'] = pd.to_datetime(df['ActivityDate'], errors='coerce')

df['ActivityDate'] = df['ActivityDate'].dt.strftime('%d/%m/%Y')

# %%
df['ActivityDate']
# Out:
# 0      12/04/2016
# 1      13/04/2016
# 2      14/04/2016
# 3      15/04/2016
# 4      16/04/2016
#           ...
# 935    08/05/2016
# 936    09/05/2016
# 937    10/05/2016
# 938    11/05/2016
# 939    12/05/2016
# Name: ActivityDate, Length: 940, dtype: object

# %%
print(df)
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   12/04/2016       13162            8.5              8.5
# 1    1503960366   13/04/2016       10735            7.0              7.0
# 2    1503960366   14/04/2016       10460            6.7              6.7
# 3    1503960366   15/04/2016        9762            6.3              6.3
# 4    1503960366   16/04/2016       12669            8.2              8.2
# ..          ...          ...         ...            ...              ...
# 935  8877689391   08/05/2016       10686            8.1              8.1
# 936  8877689391   09/05/2016       20226           18.3             18.3
# 937  8877689391   10/05/2016       10733            8.1              8.1
# 938  8877689391   11/05/2016       21420           19.6             19.6
# 939  8877689391   12/05/2016        8064            6.1              6.1
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %% [raw]
# Converted the ActivityDate column from mixed date formats into a consistent day/month/year format using pandas datetime functions and saved the cleaned dataset for further analysis.

# %% [markdown]
# # Save the cleaned dataset

# %%
df.to_csv("clean_dailyActivity.csv", index=False)

# %% [markdown]
# # Load the cleaned dataset

# %%
df = pd.read_csv("clean_dailyActivity.csv")

# %%
print(df.head())
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   12/04/2016       13162            8.5              8.5
# 1  1503960366   13/04/2016       10735            7.0              7.0
# 2  1503960366   14/04/2016       10460            6.7              6.7
# 3  1503960366   15/04/2016        9762            6.3              6.3
# 4  1503960366   16/04/2016       12669            8.2              8.2
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                 1.9                       0.6
# 1                       0.0                 1.6                       0.7
# 2                       0.0                 2.4                       0.4
# 3                       0.0                 2.1                       1.3
# 4                       0.0                 2.7                       0.4
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...
